# %%
import pandas as pd
import pyarrow.parquet as pq

# Use the actual file path (the symlink was broken)
path = "/home/sasankh/.cache/huggingface/hub/datasets--qwedsacf--competition_math/blobs/2325458edc03d786939ee9e1e5795efb9e2480247b6e1ed2c51f41bea7369c6a"

# Load the parquet file using pyarrow (more reliable)
df = pq.read_table(path).to_pandas()

# See what columns are available
print("Columns:", df.columns.tolist())
print("Shape:", df.shape)
print()

# Get the inputs from the "problem" column
inputs = df["problem"].tolist()

# Inspect a few examples
for i in range(3):
    print(f"Example {i}:")
    print(inputs[i])
    print("-----")
# Out:
# Error:
